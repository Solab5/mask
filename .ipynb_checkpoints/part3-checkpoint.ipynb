# %%
from fastai.vision.all import *
import timm

# %%
Path.BASE_PATH = path = Path('mask')

# %%
trn_path = Path('sml')

# %%
cd /notebooks/
# Out:
# /notebooks

# %%
df = pd.read_csv(path/"train_labels.csv")

# %%
resize_images(path/'images', dest=trn_path, max_size=256, recurse=True)

# %%
(path/'images').ls()
# Out:
# (#1817) [Path('images/vmjoagqsocvlzejinvgytizdxpbhzf.jpg'),Path('images/ljkyoarjjsfzpguocnnmteqqidnztx.jpg'),Path('images/tsdnumyxjxdtpmjzgsbuhaoibrbgur.jpg'),Path('images/radafdaijhzgynzcvgpdiaqpddfwrp.jpg'),Path('images/nrlywwygzrswfdbhjvdtakksrsvjgk.jpg'),Path('images/nncgaofbnlhkcvnvhajmgrxpomzzba.jpg'),Path('images/euaxozalqcqmhzyvxpiihzcvfzpcub.jpg'),Path('images/gzmchbgmbiwuyckveuenjgkutgaoqk.jpg'),Path('images/zbmmixvefcnotutstwrxzcxyjnqyul.jpg'),Path('images/wrgixgvogbvrvrvslnkuweluxuqlwq.jpg')...]

# %%
trn_path.ls()
# Out:
# (#1817) [Path('sml/vmjoagqsocvlzejinvgytizdxpbhzf.jpg'),Path('sml/ljkyoarjjsfzpguocnnmteqqidnztx.jpg'),Path('sml/tsdnumyxjxdtpmjzgsbuhaoibrbgur.jpg'),Path('sml/radafdaijhzgynzcvgpdiaqpddfwrp.jpg'),Path('sml/nrlywwygzrswfdbhjvdtakksrsvjgk.jpg'),Path('sml/nncgaofbnlhkcvnvhajmgrxpomzzba.jpg'),Path('sml/euaxozalqcqmhzyvxpiihzcvfzpcub.jpg'),Path('sml/gzmchbgmbiwuyckveuenjgkutgaoqk.jpg'),Path('sml/zbmmixvefcnotutstwrxzcxyjnqyul.jpg'),Path('sml/wrgixgvogbvrvrvslnkuweluxuqlwq.jpg')...]

# %%
dls = ImageDataLoaders.from_csv(path, 'train_labels.csv', seed = 42, folder='sml', item_tfms=Resize((256)))

# %%
dls.show_batch()

# %%
def train(arch, item, batch, folder, epochs=5):
    dls = ImageDataLoaders.from_csv(path, 'train_labels.csv', seed = 42, folder=folder, item_tfms=item, batch_tfms=batch)
    learn = vision_learner(dls, arch, metrics=error_rate).to_fp16()
    learn.fine_tune(epochs, 0.01)
    return learn

# %%
learn = train('resnet26d', item=Resize(192),
              batch=aug_transforms(size=128, min_scale=0.75))
# Out:
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/resnet26d-69e92c46.pth" to /root/.cache/torch/hub/checkpoints/resnet26d-69e92c46.pth
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.754780</td>
#       <td>0.654267</td>
#       <td>0.134100</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.443848</td>
#       <td>0.422917</td>
#       <td>0.134100</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.379606</td>
#       <td>0.214208</td>
#       <td>0.091954</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.300307</td>
#       <td>0.303333</td>
#       <td>0.099617</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.233160</td>
#       <td>0.219470</td>
#       <td>0.068966</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.190312</td>
#       <td>0.215637</td>
#       <td>0.068966</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
arch = 'convnext_small_in22k'

# %%
learn = train(arch, item=Resize(192, method='squish'),
              batch=aug_transforms(size=128, min_scale=0.75))
# Out:
# Downloading: "https://dl.fbaipublicfiles.com/convnext/convnext_small_22k_224.pth" to /root/.cache/torch/hub/checkpoints/convnext_small_22k_224.pth
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.400034</td>
#       <td>0.698216</td>
#       <td>0.065134</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.152656</td>
#       <td>0.462921</td>
#       <td>0.061303</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.157397</td>
#       <td>0.352678</td>
#       <td>0.053640</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.133254</td>
#       <td>0.277561</td>
#       <td>0.045977</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.094168</td>
#       <td>0.261473</td>
#       <td>0.038314</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.066540</td>
#       <td>0.247338</td>
#       <td>0.038314</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = train(arch, item=Resize(192),
              batch=aug_transforms(size=128, min_scale=0.75))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.443661</td>
#       <td>0.296682</td>
#       <td>0.049808</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.176407</td>
#       <td>0.196745</td>
#       <td>0.038314</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.142606</td>
#       <td>0.149313</td>
#       <td>0.038314</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.100941</td>
#       <td>0.158562</td>
#       <td>0.030651</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.087105</td>
#       <td>0.154796</td>
#       <td>0.038314</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.075226</td>
#       <td>0.144888</td>
#       <td>0.042146</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## padding

# %%
dls = ImageDataLoaders.from_csv(path, 'train_labels.csv', seed = 42, folder='sml',
    item_tfms=Resize(192, method=ResizeMethod.Pad, pad_mode=PadMode.Zeros))
dls.show_batch(max_n=3)

# %%
learn = train(arch, folder='sml',item=Resize((256), method=ResizeMethod.Pad, pad_mode=PadMode.Zeros),
      batch=aug_transforms(size=(171), min_scale=0.75))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.374775</td>
#       <td>0.639703</td>
#       <td>0.053640</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.179328</td>
#       <td>0.408877</td>
#       <td>0.053640</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.137978</td>
#       <td>0.284589</td>
#       <td>0.038314</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.111397</td>
#       <td>0.278495</td>
#       <td>0.042146</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.079235</td>
#       <td>0.279001</td>
#       <td>0.042146</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.063253</td>
#       <td>0.263123</td>
#       <td>0.038314</td>
#       <td>00:04</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Test time augumentation

# %%
valid = learn.dls.valid
preds,targs = learn.get_preds(dl=valid)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
error_rate(preds, targs)
# Out:
# TensorBase(0.0383)

# %%
learn.dls.train.show_batch(max_n=6, unique=True)

# %%
tta_preds,_ = learn.tta(dl=valid)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
error_rate(tta_preds, targs)
# Out:
# TensorBase(0.0345)

# %% [markdown]
# ## Scaling up to normal bigger images

# %%
learn = train(arch, epochs=11,
              item=Resize((480, 360), method=ResizeMethod.Pad, pad_mode=PadMode.Zeros),
              batch=aug_transforms(size=(256,192), min_scale=0.75))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.376895</td>
#       <td>0.504760</td>
#       <td>0.045977</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.116615</td>
#       <td>0.296833</td>
#       <td>0.038314</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.101463</td>
#       <td>0.165599</td>
#       <td>0.026820</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.091253</td>
#       <td>0.272353</td>
#       <td>0.042146</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.078705</td>
#       <td>0.274764</td>
#       <td>0.034483</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.073097</td>
#       <td>0.220663</td>
#       <td>0.026820</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.055078</td>
#       <td>0.220153</td>
#       <td>0.026820</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.043002</td>
#       <td>0.237285</td>
#       <td>0.034483</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.032045</td>
#       <td>0.236954</td>
#       <td>0.034483</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.023731</td>
#       <td>0.237014</td>
#       <td>0.030651</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.023013</td>
#       <td>0.232112</td>
#       <td>0.034483</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.018485</td>
#       <td>0.230272</td>
#       <td>0.030651</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = train(arch, epochs=11, item=Resize(480, method='squish'),
              batch=aug_transforms(size=256, min_scale=0.75))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.279194</td>
#       <td>0.271051</td>
#       <td>0.022989</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.065772</td>
#       <td>0.162950</td>
#       <td>0.015326</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.069865</td>
#       <td>0.104459</td>
#       <td>0.019157</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.046742</td>
#       <td>0.150849</td>
#       <td>0.022989</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.045174</td>
#       <td>0.121975</td>
#       <td>0.015326</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.045372</td>
#       <td>0.166936</td>
#       <td>0.026820</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.037808</td>
#       <td>0.188046</td>
#       <td>0.015326</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.033155</td>
#       <td>0.162721</td>
#       <td>0.015326</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.028152</td>
#       <td>0.142078</td>
#       <td>0.015326</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.022797</td>
#       <td>0.134240</td>
#       <td>0.015326</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.016906</td>
#       <td>0.137057</td>
#       <td>0.015326</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.013037</td>
#       <td>0.135486</td>
#       <td>0.015326</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
tta_preds,targs = learn.tta(dl=learn.dls.valid)
error_rate(tta_preds, targs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='11' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# TensorBase(0.0153)

# %%
files = get_image_files(path/'images')
files
# Out:
# (#1817) [Path('images/vmjoagqsocvlzejinvgytizdxpbhzf.jpg'),Path('images/ljkyoarjjsfzpguocnnmteqqidnztx.jpg'),Path('images/tsdnumyxjxdtpmjzgsbuhaoibrbgur.jpg'),Path('images/radafdaijhzgynzcvgpdiaqpddfwrp.jpg'),Path('images/nrlywwygzrswfdbhjvdtakksrsvjgk.jpg'),Path('images/nncgaofbnlhkcvnvhajmgrxpomzzba.jpg'),Path('images/euaxozalqcqmhzyvxpiihzcvfzpcub.jpg'),Path('images/gzmchbgmbiwuyckveuenjgkutgaoqk.jpg'),Path('images/zbmmixvefcnotutstwrxzcxyjnqyul.jpg'),Path('images/wrgixgvogbvrvrvslnkuweluxuqlwq.jpg')...]

# %%
train_list = df.image.to_list()
train_list[:4]
# Out:
# ['tfymlmdkpzkqdjhdxyhnoeuqszxphw.jpg',
#  'rxgismgsvmaayzjarbfjaljhqmpbrt.jpg',
#  'uuzshfrhkgrkolhwdvliqauzulurnz.jpg',
#  'mjspxsagzusaznvnyxgamtrlqkqklp.jpg']

# %%
splitter = FuncSplitter(lambda o: Path(o).name not in train_list)
new_files = splitter(files)
train, test = new_files

# %%
train_path, test_path = files[train], files[test]

# %%
ss = pd.read_csv(path/'SampleSubmission.csv')
ss
# Out:
#                                   image  target
# 0    aadawlxbmapqrblgxyzarhjasgiobu.png       0
# 1    abpxvdfyhaaohzcrngcucmhffwizxs.jpg       0
# 2    aclkjfvackiieiznzfcwienplielrj.jpg       0
# 3    aelkivmayxgsdjosiibfgmkvfrjvjk.jpg       0
# 4    aelzzshpfxerelefnkatpczktuxjln.jpg       0
# ..                                  ...     ...
# 504  zpfhbgixcctxylnihhrepjgcmjksvf.jpg       0
# 505  zuignwckjykxefmpubjpjefvhghaoi.jpg       0
# 506  zuxvwdblfwjpibjexgfglpyreqslhs.jpg       0
# 507  zvyajojutzgqumdjfxxkpiuuxeefyy.jpg       0
# 508  zynasgxnxnzqaallnvkthegctommtu.jpg       0
#
# [509 rows x 2 columns]

# %%
tst_files = test_path.sorted()
tst_dl = dls.test_dl(tst_files)

# %%
preds,_ = learn.tta(dl=tst_dl)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='11' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
preds
# Out:
# TensorBase([[3.4778e-02, 9.6522e-01],
#             [9.9924e-01, 7.5841e-04],
#             [8.2522e-11, 1.0000e+00],
#             ...,
#             [9.9326e-01, 6.7371e-03],
#             [1.2948e-10, 1.0000e+00],
#             [6.0207e-02, 9.3979e-01]])

# %%
x = torch.max(preds, 1)

# %%
x[0][:4]
# Out:
# TensorBase([0.9652, 0.9992, 1.0000, 1.0000])

# %%
y = torch.argmax(preds, dim=1)

# %%
y[:4]
# Out:
# TensorBase([1, 0, 1, 1])

# %%
res = torch.where(y==0, 1-x[0], x[0])

# %%
results = pd.Series(res.numpy(), name="target").round(2)
results
# Out:
# 0      0.97
# 1      0.00
# 2      1.00
# 3      1.00
# 4      0.00
#        ...
# 504    0.00
# 505    0.00
# 506    0.01
# 507    1.00
# 508    0.94
# Name: target, Length: 509, dtype: float32

# %%
ss['target'] = results
ss.to_csv('subm2.csv', index=False)
# !head subm2.csv
# Out:
# image,target
# aadawlxbmapqrblgxyzarhjasgiobu.png,0.97
# abpxvdfyhaaohzcrngcucmhffwizxs.jpg,0.0
# aclkjfvackiieiznzfcwienplielrj.jpg,1.0
# aelkivmayxgsdjosiibfgmkvfrjvjk.jpg,1.0
# aelzzshpfxerelefnkatpczktuxjln.jpg,0.0
# ajnjnkvstqesvfohaptobyasrkmcnq.jpg,0.0
# akkydnvilgvzigllmboonbqbbioocs.jpg,1.0
# akvjfjhgayyjwrqrczjbeyoqhhajis.jpg,0.02
# alcveyvosnywyjbmngolmnblftdoje.jpg,0.0
